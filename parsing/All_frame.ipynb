# %%
import pandas as pd

# %% [markdown]
# # Импорт датафреймов

# %% [markdown]
# ### Резюме SupeerJob (df_1)

# %%
df_1 = pd.read_csv('/content/drive/MyDrive/Палата №6/csv/df_superjob.csv')
print(df_1.shape)
df_1.head()
# Out:
# (29, 11)
#                                            должность           зарплата  \
# 0  Руководитель, ведущий специалист информационно...  По договорённости
# 1                                    Product analyst  По договорённости
# 2                             Junior Product manager  По договорённости
# 3                                    Аналитик данных  По договорённости
# 4                                 Системный аналитик           50 000 ₽
#
#                                               навыки             обновление  \
# 0    ['Аналитика', 'Другое', 'Управление проектами']       Oбновлено в 7:21
# 1  ['SQL', 'Python', 'Excel', 'MS Excel', 'Tablea...  Oбновлено 27 сентября
# 2  ['•\tФормализация бизнес-требований', '•\tАнал...  Oбновлено 27 сентября
# 3  ['Сбор и анализ информации', 'Аналитическое мы...      Oбновлено в 13:47
# 4                                      ['Аналитика']      Oбновлено в 13:28
#
# ...

# %% [markdown]
# ### Резюме ГородРабот.ру (df_2)

# %%
df_2=pd.read_csv('/content/drive/MyDrive/Палата №6/csv/gorodrabot.ru-resumes.csv', sep='\t')
print(df_2.shape)
df_2.head()
# Out:
# (2731, 21)
#         id         source             town  \
# 0  5338410  gorodrabot.ru           Москва
# 1  5348625  gorodrabot.ru           Москва
# 2  5231495  gorodrabot.ru  Санкт-Петербург
# 3  5310489  gorodrabot.ru          Иркутск
# 4      862  gorodrabot.ru        Хабаровск
#
#                                                 name                    date  \
# 0                                    Аналитик данных   8 октября 2022, 18:58
# 1                                    Аналитик данных     7 марта 2023, 10:09
# 2                           Аналитик/дата-сайентист;  11 декабря 2019, 13:05
# 3                                     Химик-аналитик   11 января 2022, 11:55
# 4  Маркетолог-аналитик. Директолог. СЕО- специали...    7 апреля 2015, 06:28
#
#      salary                                   url  \
# 0       NaN  https://gorodrabot.ru/resume/5338410
# 1   70000.0  https://gorodrabot.ru/resume/5348625
# 2  100000.0  https://gorodrabot.ru/resume/5231495
# ...

# %% [markdown]
# ### Резюме Joblab (df_3)

# %%
df_3 = pd.read_csv('/content/drive/MyDrive/Палата №6/csv/joblab(резюме).csv')
print(df_3.shape)
df_3.head()
# Out:
# (1110, 8)
#                                            должность место_проживания  \
# 0  Руководитель проекта, Инженер проекта, Исполни...        Тушинская
# 1                                    Project Manager           Мытищи
# 2  Product Manager, Менеджер по продукту/Project ...        Технопарк
# 3  Проектный менеджер (стажер)/ Junior project ma...       Новокосино
# 4                                    Project manager     Полежаевская
#
#     возраст желаемая_зарплата                         опыт  \
# 0    41 год     от 1 000 руб.           Опыт работы 17 лет
# 1    41 год   от 150 000 руб.  Опыт работы 5 лет 8 месяцев
# 2   34 года   от 180 000 руб.  Опыт работы 9 лет 9 месяцев
# 3   23 года        договорная           Опыт работы 2 года
# 4    28 лет   от 120 000 руб.  Опыт работы 6 лет 8 месяцев
#
#                                         место_работы  \
# 0  01.2022 - 10.2023 – Ведущий асессор 1 категори...
# 1  08.2022 - 10.2023 – Администратор IT проекта 0...
# ...

# %% [markdown]
# ### Резюме RemoteJob (обрезаны) (df_4)

# %%
df_4=pd.read_csv('/content/drive/MyDrive/Палата №6/csv/remote_jobs20.csv')
print(df_4.shape)
df_4.head()
# Out:
# (3460, 4)
#                Вакансия     Зарплата   Местоположение  \
# 0              Дизайнер  40 000 руб.  Город не указан
# 1     Junior - дизайнер  30 000 руб.  Город не указан
# 2            Веб-дизайн  30 000 руб.  Город не указан
# 3          Веб-дизайнер  20 000 руб.  Город не указан
# 4  Графический дизайнер  40 000 руб.  Город не указан
#
#                                             Описание
# 0  Добрый день. Я дизайнер с небольшим опытом раб...
# 1  Здравствуйте, меня зовут Виктория. Мне 23 года...
# 2  Всем привет! Меня зовут Катя! Делаю лендинги, ...
# 3  Добрый день. В поиске стажировки и работы на п...
# 4  Художник-дизайнер Дизайн эскизов для клиентов,...

# %% [markdown]
# ### Вакансии RemoteJob (df_5)

# %%
df_5=pd.read_csv('/content/drive/MyDrive/Палата №6/csv/remotejob(вакансии).csv', sep=';')
print(df_5.shape)
df_5.head()
# Out:
# (2864, 9)
#      наименование компании                             наименование должности  \
# 0  Finstar Financial Group        System analyst (Vietnam) (удаленная работа)
# 1      Advantage Solutions                  System analyst (удаленная работа)
# 2                 Интелкон  Системный аналитик / System Analyst (удаленная...
# 3      Анлимитед Продакшен  Системный аналитик / Systems Analyst (удаленна...
# 4                 Soft Jet  Системный аналитик/System Analyst Middle+ (уда...
#
#                      зарплата опыт работы  \
# 0  от 194 004 до 339 507 руб.   Не указан
# 1             з.п. не указана   Не указан
# 2  от 200 000 до 250 000 руб.   Не указан
# 3             з.п. не указана   Не указан
# 4  от 150 000 до 250 000 руб.   Не указан
#
#                                             описание город     формат работы  \
# 0  <p> <strong> Finstar Financial Group</strong> ...     -  удаленная работа
# ...

# %% [markdown]
# ### Резюме SuperJob (df_6)

# %%
df_6=pd.read_csv('/content/drive/MyDrive/Палата №6/csv/resume_superjob.csv')
print(df_6.shape)
df_6.head()
# Out:
# (1812, 10)
#                                            Должность           Зарплата  \
# 0  Junior Data scientist / Junior Neural networks...  По договорённости
# 1                                     Data Scientist           45 000 ₽
# 2          Machine Learning Engineer, Data Scientist           80 000 ₽
# 3                              Junior Data Scientist  По договорённости
# 4                                     Data Scientist  По договорённости
#
#                                       Местоположение          Тип занятости  \
# 0                      Москва, готов к командировкам             не указано
# 1  Рязань, готов к переезду: Москва, готов к кома...       полная занятость
# 2                   Иннополис, готов к командировкам       полная занятость
# 3  Волгоград, готов к переезду, не готов к команд...       полная занятость
# 4         Санкт-Петербург, не готова к командировкам  неполный рабочий день
#
# ...

# %% [markdown]
# ### Вакансии Хабр (df_7)

# %%
df_7=pd.read_csv('/content/drive/MyDrive/Палата №6/csv/vacancy.csv')
print(df_7.shape)
df_7.head()
# Out:
# (25, 8)
#   Название компании                                         Вакансия  \
# 0              Сбер                                   Data scientist
# 1                VK                      Android-разработчик (Почта)
# 2             YADRO  Senior Software Engineer C (Linux kernel space)
# 3               МТС         Менеджер по работе с клиентами Cloud MTC
# 4          Банк ПСБ                             Администратор Hadoop
#
#                               Требования по вакансии  \
# 0  Ученый по данным, Средний (Middle) • Git • SQL...
# 1  Разработчик мобильных приложений, Старший (Sen...
# 2  Бэкенд разработчик, Старший (Senior) • Linux k...
# 3  Менеджер по работе с клиентами • Saas • Управл...
# 4  Администратор баз данных, Средний (Middle) • A...
#
#                                        Город, уловия                 Зарплата  \
# 0                       Москва • Полный рабочий день             от 200 000 ₽
# ...

# %% [markdown]
# ### Резюме JobLab 2 (df_8)

# %%
df_8=pd.read_csv('/content/drive/MyDrive/Палата №6/csv/joblab2(резюме).csv')
print(df_8.shape)
df_8.head()
# Out:
# (1110, 12)
#                                            должность место_проживания  \
# 0  Руководитель проекта, Инженер проекта, Исполни...        Тушинская
# 1                                    Project Manager           Мытищи
# 2  Product Manager, Менеджер по продукту/Project ...        Технопарк
# 3  Проектный менеджер (стажер)/ Junior project ma...       Новокосино
# 4                                    Project manager     Полежаевская
#
#     возраст желаемая_зарплата                  опыт_работы  \
# 0    41 год     от 1 000 руб.           Опыт работы 17 лет
# 1    41 год   от 150 000 руб.  Опыт работы 5 лет 8 месяцев
# 2   34 года   от 180 000 руб.  Опыт работы 9 лет 9 месяцев
# 3   23 года        договорная           Опыт работы 2 года
# 4    28 лет   от 120 000 руб.  Опыт работы 6 лет 8 месяцев
#
#                                         место_работы  \
# 0  01.2022 - 10.2023 – Ведущий асессор 1 категори...
# 1  08.2022 - 10.2023 – Администратор IT проекта 0...
# ...

# %% [markdown]
# ### Резюме SuperJob (df_9)

# %%
df_9=pd.read_csv('/content/drive/MyDrive/Палата №6/csv/clean_superjob_resume.csv')
print(df_9.shape)
df_9.head()
# Out:
# (1812, 13)
#                                            Должность           Зарплата  \
# 0  Junior Data scientist / Junior Neural networks...  По договорённости
# 1                                     Data Scientist           45 000 ₽
# 2          Machine Learning Engineer, Data Scientist           80 000 ₽
# 3                              Junior Data Scientist  По договорённости
# 4                                     Data Scientist  По договорённости
#
#     Местоположение          Тип занятости  \
# 0           Москва             не указано
# 1   Рязань, Москва       полная занятость
# 2        Иннополис       полная занятость
# 3        Волгоград       полная занятость
# 4  Санкт-Петербург  неполный рабочий день
#
#                                              Возраст         Опыт работы  \
# 0  36 лет (родился 22 декабря 1986), не состоит в...   12 лет и 2 месяца
# 1                   30 лет (родился 04 августа 1993)  8 лет и 11 месяцев
# ...

# %% [markdown]
# ### Резюме SuperJob (df_10)

# %%
df_10=pd.read_csv('/content/drive/MyDrive/Палата №6/csv/resums_superjob_analytics.csv')
print(df_10.shape)
df_10.head()
# Out:
# (5024, 14)
#                                            Должность           Зарплата  \
# 0  Руководитель, ведущий специалист информационно...  По договорённости
# 1                                         Нет данных         Нет данных
# 2                                 Системный аналитик  По договорённости
# 3                                    Аналитик данных           80 000 ₽
# 4                                           Аналитик  По договорённости
#
#   Местоположение     Тип занятости     Возраст         Пол  \
# 0   Новомосковск        не указано          53           М
# 1     Нет данных        Нет данных  Нет данных  Нет данных
# 2         Москва  полная занятость  Нет данных           Ж
# 3         Москва  полная занятость          69           М
# 4         Москва  полная занятость          43           Ж
#
#            Опыт работы                             Последнее место работы  \
# 0  23 года и 6 месяцев  Исследователь общественно-политических и социа...
# ...

# %% [markdown]
# ### Резюме Remote-Job (df_11)

# %%
df_11=pd.read_csv('/content/drive/MyDrive/Палата №6/csv/RJ_3126_new_final_6.csv')
print(df_11.shape)
df_11.head()
# Out:
# (3123, 7)
#                                                Title  \
# 0                                       Data Analyst
# 1                     Сетевой инженер и безопасность
# 2                                         Researcher
# 3  Data Analyst / Аналитик данных (SQL, Английски...
# 4  Аналитик / переводчик (чешский/английский) / т...
#
#                                          Resume Link  \
# 0  https://remote-job.ru/resume/show/75137/data-a...
# 1  https://remote-job.ru/resume/show/70981/setevo...
# 2  https://remote-job.ru/resume/show/58070/resear...
# 3  https://remote-job.ru/resume/show/73775/data-a...
# 4  https://remote-job.ru/resume/show/46389/analit...
#
#                                             Название Уровень зарплаты  \
# 0                                       Data Analyst   от 70 000 руб.
# 1                     Сетевой инженер и безопасность    от 3 000 руб.
# 2                                         Researcher  от 120 000 руб.
# ...

# %% [markdown]
# ### GorodRabot-resume-data (df_comp)

# %%
df_comp = pd.read_excel('/content/drive/MyDrive/Палата №6/csv/GorodRabot-resume-data.xlsx')
df_comp.head()
# Out:
#                                 educational_facility      educational_level  \
# 0          Колледж связи № 54 имени П.М. Вострухина.   высшее (специалитет)
# 1  РИИЖТ, г. Ростов-на-Дону   Заочная  С 1982-198...   высшее (специалитет)
# 2               Тюменский индустриальный университет   высшее (аспирантура)
# 3  ''Хитачи Констракшн Машинери Ко., ЛТД'' ''Челя...   высшее (бакалавриат)
# 4  (СГА) Современная гуманитарная академия г. Москва  высшее (магистратура)
#
#                                       specialization  \
# 0  Economics of the enterprise, "Statistics for d...
# 1  Вычислительные машины комплексы, системы, сет\...
# 2                    Как создать контент для бизнеса
# 3                             Менеджмент организации
# 4                         Основы интернет-маркетинга
#
#                                             position         language  \
# 0  (Устроиться на интересную работу с достойной о...  Азербайджанский
# ...
